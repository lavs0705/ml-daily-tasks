# %% [markdown]
# # List

# %%
l=[]
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[1,2,3,4,5,6]
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.append(7)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
l.insert(1,8)
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6, 7]

# %%
l.pop()
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6]

# %%
l.pop(1)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.remove(5)
print(1)
# Out:
# 1

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.append(l2)
print(l1)
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.extend(l2)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(l)
# Out:
# [1, 2, 3, 4, 6]

# %%
l.clear()
print(l)
# Out:
# []

# %%
l=[1,5,6,8,2,8,9]
l.sort()
print(l)
# Out:
# [1, 2, 5, 6, 8, 8, 9]

# %%
l=[1,5,6,8,2,8,9]
print(sorted(l))
# Out:
# [1, 2, 5, 6, 8, 8, 9]

# %%
l=[1,5,4,6,7,9,7,3]
l.reverse()
print(l)
# Out:
# [3, 7, 9, 7, 6, 4, 5, 1]

# %% [markdown]
# # Dictionary

# %%
d={}
print(d)
print(type(d))
# Out:
# {}
# <class 'dict'>

# %%
d={"name":"lavanya","city":"kakinada"}
print(d)
# Out:
# {'name': 'lavanya', 'city': 'kakinada'}

# %%
print(d["name"])
# Out:
# lavanya

# %%
d["mobile_number"]=8639735476
print(d)
# Out:
# {'name': 'lavanya', 'city': 'kakinada', 'mobile_number': 8639735476}

# %%
d["city"]="Hyd"
print(d)
# Out:
# {'name': 'lavanya', 'city': 'Hyd', 'mobile_number': 8639735476}

# %%
print(d.keys())
# Out:
# dict_keys(['name', 'city', 'mobile_number'])

# %%
print(d.values())
# Out:
# dict_values(['lavanya', 'Hyd', 8639735476])

# %%
print(d.items())
# Out:
# dict_items([('name', 'lavanya'), ('city', 'Hyd'), ('mobile_number', 8639735476)])

# %% [markdown]
# # File Handling

# %%
f=open('abc.txt','w')
print('file name :',f.name)
print('file mode :',f.mode)
print(f.readable())
print(f.writable())
print(f.closed)
f.close()
print(f.closed)
# Out:
# file name : abc.txt
# file mode : w
# False
# True
# False
# True

# %% [markdown]
# # Reading a files

# %%
with open("abc.txt","r") as file:
    content=file.read()
print(content)

# %%
with open("abc.txt","r") as file:
    content=file.read(10)
print(content)

# %%
with open("abc.txt","r") as file:
    content=file.readline()
print(content)

# %%
with open("abc.txt","r") as file:
    content=file.readlines()
print(content)
# Out:
# []

# %% [markdown]
# # Writing files

# %%
with open("abc.text","w") as file:
    file.write("Aditya degree college")

# %%
l=["ADC\n","KKD\n","AP\n"]
with open("abc.txt","w")as file:
    file.writelines(l)

# %%
with open("abc.txt","a") as file:
    file.write("533033")
